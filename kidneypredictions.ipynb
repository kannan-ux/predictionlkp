# %%
! kaggle datasets list -s "kidney_disease"
# Out:
# ref                                   title                   size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------  ----------------------  ----  -------------------  -------------  ---------  ---------------
# imnoob/kidney-disease                 Kidney_disease          10KB  2021-07-10 17:56:24            226         15  0.1764706
# nishantmahajan88/kidney-disease       kidney_disease          10KB  2021-09-11 12:40:50             67          3  0.1764706
# shvahidian/kidney-disease             kidney_disease          10KB  2021-08-09 05:45:15             45          2  0.1764706
# tushar552/kidney-disease              kidney_disease          10KB  2024-09-05 15:26:58              3          1  0.23529412
# madapatiashok/kidney-disease          kidney_disease          10KB  2024-01-04 11:40:31             11          0  0.23529412
# ...

# %%
! kaggle datasets download -d "imnoob/kidney-disease"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/imnoob/kidney-disease
# License(s): unknown
# kidney-disease.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
with zipfile.ZipFile("kidney-disease.zip","r")as file:
    file.extractall("sakth")

# %%
import os
os.listdir("sakth")
# Out:
# ['kidney_disease.csv',
#  'orders.csv',
#  'parkinsons.data',
#  'parkinsons.names',
#  'pixar_rotten_tomatoes.csv',
#  'rotten_tomatoes_critic_reviews.csv',
#  'rotten_tomatoes_movies.csv',
#  'Rotten_Tomatoes_Movies3.xls',
#  'rt_reviews.csv',
#  'Videos',
#  '__MACOSX']

# %%
import pandas as pd
df=pd.read_csv("sakth/kidney_disease.csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df.drop('id',axis=1,inplace=True)

# %%
df
# Out:
#       age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...    ...  ...  ...     ...       ...         ...         ...
# 395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent  notpresent
# 398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
# 399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent  notpresent
#
# ...

# %%
X=df[['age','bp','sg','al','su','rbc','pc','bgr','sc','sod','pot','hemo','pcv','wc','rc','htn','appet']]

# %%
X.rename(columns={"bp":"blood_pressure","sg":"specificGravity","al":"aluminum","su":"sugar","rbc":"redblood","pc":"pucells","bgr":"bloodureanitrogen","sc":"serumcrestine","sod":"sodium","pot":"potassium","hemo":"hemoglobin","pcv":"packedcellvolumne","wc":"whitebloodcells","rc":"redbloodcells","htn":"hypertension","appet":"appetite"},inplace=True)
# Out:
# C:\Users\sakth\AppData\Local\Temp\ipykernel_15524\1473304021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.rename(columns={"bp":"blood_pressure","sg":"specificGravity","al":"aluminum","su":"sugar","rbc":"redblood","pc":"pucells","bgr":"bloodureanitrogen","sc":"serumcrestine","sod":"sodium","pot":"potassium","hemo":"hemoglobin","pcv":"packedcellvolumne","wc":"whitebloodcells","rc":"redbloodcells","htn":"hypertension","appet":"appetite"},inplace=True)

# %%
X.rename(columns={"whitebloodcells":"whitebloodcellscount","redbloodcells":"redbloodcellscount"},inplace=True)
# Out:
# C:\Users\sakth\AppData\Local\Temp\ipykernel_15524\783312362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.rename(columns={"whitebloodcells":"whitebloodcellscount","redbloodcells":"redbloodcellscount"},inplace=True)

# %%
X
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar redblood  \
# 0    48.0            80.0            1.020       1.0    0.0      NaN
# 1     7.0            50.0            1.020       4.0    0.0      NaN
# 2    62.0            80.0            1.010       2.0    3.0   normal
# 3    48.0            70.0            1.005       4.0    0.0   normal
# 4    51.0            80.0            1.010       2.0    0.0   normal
# ..    ...             ...              ...       ...    ...      ...
# 395  55.0            80.0            1.020       0.0    0.0   normal
# 396  42.0            70.0            1.025       0.0    0.0   normal
# 397  12.0            80.0            1.020       0.0    0.0   normal
# 398  17.0            60.0            1.025       0.0    0.0   normal
# 399  58.0            80.0            1.025       0.0    0.0   normal
#
#       pucells  bloodureanitrogen  serumcrestine  sodium  potassium  \
# 0      normal              121.0            1.2     NaN        NaN
# ...

# %%
Y=df[['classification']]

# %%
Y.rename(columns={"classification":"status"},inplace=True)
# Out:
# C:\Users\sakth\AppData\Local\Temp\ipykernel_15524\2299746782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Y.rename(columns={"classification":"status"},inplace=True)

# %%
import warnings
warnings.filterwarnings("ignore")
Y
# Out:
#      status
# 0       ckd
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# ..      ...
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [400 rows x 1 columns]

# %%
Y['status'].value_counts()
# Out:
# status
# ckd       248
# notckd    150
# ckd\t       2
# Name: count, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   391 non-null    float64
#  1   blood_pressure        388 non-null    float64
#  2   specificGravity       353 non-null    float64
#  3   aluminum              354 non-null    float64
#  4   sugar                 351 non-null    float64
#  5   redblood              248 non-null    object
#  6   pucells               335 non-null    object
#  7   bloodureanitrogen     356 non-null    float64
#  8   serumcrestine         383 non-null    float64
#  9   sodium                313 non-null    float64
#  10  potassium             312 non-null    float64
#  11  hemoglobin            348 non-null    float64
#  12  packedcellvolumne     330 non-null    object
#  13  whitebloodcellscount  295 non-null    object
# ...

# %%
X.isnull().sum()
# Out:
# age                       9
# blood_pressure           12
# specificGravity          47
# aluminum                 46
# sugar                    49
# redblood                152
# pucells                  65
# bloodureanitrogen        44
# serumcrestine            17
# sodium                   87
# potassium                88
# hemoglobin               52
# packedcellvolumne        70
# whitebloodcellscount    105
# redbloodcellscount      130
# hypertension              2
# appetite                  1
# dtype: int64

# %%
X.age.unique()
# Out:
# array([48.,  7., 62., 51., 60., 68., 24., 52., 53., 50., 63., 40., 47.,
#        61., 21., 42., 75., 69., nan, 73., 70., 65., 76., 72., 82., 46.,
#        45., 35., 54., 11., 59., 67., 15., 55., 44., 26., 64., 56.,  5.,
#        74., 38., 58., 71., 34., 17., 12., 43., 41., 57.,  8., 39., 66.,
#        81., 14., 27., 83., 30.,  4.,  3.,  6., 32., 80., 49., 90., 78.,
#        19.,  2., 33., 36., 37., 23., 25., 20., 29., 28., 22., 79.])

# %%
X['age'].fillna(X['age'].mean(),inplace=True)

# %%
X.age.isnull().sum()
# Out:
# 0

# %%
X['age']=X['age'].astype("int")

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    int32
#  1   blood_pressure        388 non-null    float64
#  2   specificGravity       353 non-null    float64
#  3   aluminum              354 non-null    float64
#  4   sugar                 351 non-null    float64
#  5   redblood              248 non-null    object
#  6   pucells               335 non-null    object
#  7   bloodureanitrogen     356 non-null    float64
#  8   serumcrestine         383 non-null    float64
#  9   sodium                313 non-null    float64
#  10  potassium             312 non-null    float64
#  11  hemoglobin            348 non-null    float64
#  12  packedcellvolumne     330 non-null    object
#  13  whitebloodcellscount  295 non-null    object
# ...

# %%
X.blood_pressure.unique()
# Out:
# array([ 80.,  50.,  70.,  90.,  nan, 100.,  60., 110., 140., 180., 120.])

# %%
X['blood_pressure'].fillna(X['blood_pressure'].mean(),inplace=True)

# %%
X['blood_pressure']=X['blood_pressure'].astype("int")

# %%
X.blood_pressure.isnull().sum()
# Out:
# 0

# %%
X.isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specificGravity          47
# aluminum                 46
# sugar                    49
# redblood                152
# pucells                  65
# bloodureanitrogen        44
# serumcrestine            17
# sodium                   87
# potassium                88
# hemoglobin               52
# packedcellvolumne        70
# whitebloodcellscount    105
# redbloodcellscount      130
# hypertension              2
# appetite                  1
# dtype: int64

# %%
X.blood_pressure.isnull().sum()
# Out:
# 0

# %%
X.aluminum.unique()
# Out:
# array([ 1.,  4.,  2.,  3.,  0., nan,  5.])

# %%
X['aluminum'].fillna(X['aluminum'].mean(),inplace=True)

# %%
X['aluminum']=X['aluminum'].astype("int")

# %%
X.sugar.unique()
# Out:
# array([ 0.,  3.,  4.,  1., nan,  2.,  5.])

# %%
X['sugar'].fillna(X['sugar'].mean(),inplace=True)

# %%
X['sugar']=X['sugar'].astype("int")

# %%
X.sugar.isnull().sum()
# Out:
# 0

# %%
X.redblood.value_counts()
# Out:
# redblood
# normal      201
# abnormal     47
# Name: count, dtype: int64

# %%
X.redblood.unique()
# Out:
# array([nan, 'normal', 'abnormal'], dtype=object)

# %%
X['redblood'].fillna('normal',inplace=True)

# %%
X['redblood']=X['redblood'].astype("category")

# %%
X.redblood.isnull().sum()
# Out:
# 0

# %%
X
# Out:
#      age  blood_pressure  specificGravity  aluminum  sugar redblood   pucells  \
# 0     48              80            1.020         1      0   normal    normal
# 1      7              50            1.020         4      0   normal    normal
# 2     62              80            1.010         2      3   normal    normal
# 3     48              70            1.005         4      0   normal  abnormal
# 4     51              80            1.010         2      0   normal    normal
# ..   ...             ...              ...       ...    ...      ...       ...
# 395   55              80            1.020         0      0   normal    normal
# 396   42              70            1.025         0      0   normal    normal
# 397   12              80            1.020         0      0   normal    normal
# 398   17              60            1.025         0      0   normal    normal
# 399   58              80            1.025         0      0   normal    normal
#
# ...

# %%
X.pucells.value_counts()
# Out:
# pucells
# normal      259
# abnormal     76
# Name: count, dtype: int64

# %%
X.pucells.unique()
# Out:
# array(['normal', 'abnormal', nan], dtype=object)

# %%
X.pucells.isnull().sum()
# Out:
# 65

# %%
X['pucells'].fillna('normal',inplace=True)

# %%
X['pucells']=X['pucells'].astype("category")

# %%
X.isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specificGravity          47
# aluminum                  0
# sugar                     0
# redblood                  0
# pucells                   0
# bloodureanitrogen        44
# serumcrestine            17
# sodium                   87
# potassium                88
# hemoglobin               52
# packedcellvolumne        70
# whitebloodcellscount    105
# redbloodcellscount      130
# hypertension              2
# appetite                  1
# dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    int32
#  1   blood_pressure        400 non-null    int32
#  2   specificGravity       353 non-null    float64
#  3   aluminum              400 non-null    int32
#  4   sugar                 400 non-null    int32
#  5   redblood              400 non-null    category
#  6   pucells               400 non-null    category
#  7   bloodureanitrogen     356 non-null    float64
#  8   serumcrestine         383 non-null    float64
#  9   sodium                313 non-null    float64
#  10  potassium             312 non-null    float64
#  11  hemoglobin            348 non-null    float64
#  12  packedcellvolumne     330 non-null    object
#  13  whitebloodcellscount  295 non-null    object
#  14  redbloodcellscount    270 non-null    object
# ...

# %%
X.specificGravity.unique()
# Out:
# array([1.02 , 1.01 , 1.005, 1.015,   nan, 1.025])

# %%
X['specificGravity'].fillna(X['specificGravity'].mean(),inplace=True)

# %%
X['specificGravity']=X['specificGravity'].astype("int")

# %%
X.bloodureanitrogen.unique()
# Out:
# array([121.,  nan, 423., 117., 106.,  74., 100., 410., 138.,  70., 490.,
#        380., 208.,  98., 157.,  76.,  99., 114., 263., 173.,  95., 108.,
#        156., 264., 123.,  93., 107., 159., 140., 171., 270.,  92., 137.,
#        204.,  79., 207., 124., 144.,  91., 162., 246., 253., 141., 182.,
#         86., 150., 146., 425., 112., 250., 360., 163., 129., 133., 102.,
#        158., 165., 132., 104., 127., 415., 169., 251., 109., 280., 210.,
#        219., 295.,  94., 172., 101., 298., 153.,  88., 226., 143., 115.,
#         89., 297., 233., 294., 323., 125.,  90., 308., 118., 224., 128.,
#        122., 214., 213., 268., 256.,  84., 105., 288., 139.,  78., 273.,
#        242., 424., 303., 148., 160., 192., 307., 220., 447., 309.,  22.,
#        111., 261., 215., 234., 131., 352.,  80., 239., 110., 130., 184.,
#        252., 113., 230., 341., 255., 103., 238., 248., 120., 241., 269.,
#        201., 203., 463., 176.,  82., 119.,  97.,  96.,  81., 116., 134.,
# ...

# %%
X['bloodureanitrogen'].fillna(X['bloodureanitrogen'].mean(),inplace=True)

# %%
X['bloodureanitrogen']=X['bloodureanitrogen'].astype("int")

# %%
X.isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specificGravity           0
# aluminum                  0
# sugar                     0
# redblood                  0
# pucells                   0
# bloodureanitrogen         0
# serumcrestine            17
# sodium                   87
# potassium                88
# hemoglobin               52
# packedcellvolumne        70
# whitebloodcellscount    105
# redbloodcellscount      130
# hypertension              2
# appetite                  1
# dtype: int64

# %%
X.serumcrestine.unique()
# Out:
# array([ 1.2 ,  0.8 ,  1.8 ,  3.8 ,  1.4 ,  1.1 , 24.  ,  1.9 ,  7.2 ,
#         4.  ,  2.7 ,  2.1 ,  4.6 ,  4.1 ,  9.6 ,  2.2 ,  5.2 ,  1.3 ,
#         1.6 ,  3.9 , 76.  ,  7.7 ,   nan,  2.4 ,  7.3 ,  1.5 ,  2.5 ,
#         2.  ,  3.4 ,  0.7 ,  1.  , 10.8 ,  6.3 ,  5.9 ,  0.9 ,  3.  ,
#         3.25,  9.7 ,  6.4 ,  3.2 , 32.  ,  0.6 ,  6.1 ,  3.3 ,  6.7 ,
#         8.5 ,  2.8 , 15.  ,  2.9 ,  1.7 ,  3.6 ,  5.6 ,  6.5 ,  4.4 ,
#        10.2 , 11.5 ,  0.5 , 12.2 ,  5.3 ,  9.2 , 13.8 , 16.9 ,  6.  ,
#         7.1 , 18.  ,  2.3 , 13.  , 48.1 , 14.2 , 16.4 ,  2.6 ,  7.5 ,
#         4.3 , 18.1 , 11.8 ,  9.3 ,  6.8 , 13.5 , 12.8 , 11.9 , 12.  ,
#        13.4 , 15.2 , 13.3 ,  0.4 ])

# %%
X['serumcrestine'].fillna(X['serumcrestine'].mean(),inplace=True)

# %%
X['serumcrestine']=X['serumcrestine'].astype("int")

# %%
X.isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specificGravity           0
# aluminum                  0
# sugar                     0
# redblood                  0
# pucells                   0
# bloodureanitrogen         0
# serumcrestine             0
# sodium                   87
# potassium                88
# hemoglobin               52
# packedcellvolumne        70
# whitebloodcellscount    105
# redbloodcellscount      130
# hypertension              2
# appetite                  1
# dtype: int64

# %%
X.sodium.unique()
# Out:
# array([  nan, 111. , 142. , 104. , 114. , 131. , 138. , 135. , 130. ,
#        141. , 139. ,   4.5, 136. , 129. , 140. , 132. , 133. , 134. ,
#        125. , 163. , 137. , 128. , 143. , 127. , 146. , 126. , 122. ,
#        147. , 124. , 115. , 145. , 113. , 120. , 150. , 144. ])

# %%
X['sodium'].fillna(X['sodium'].mean(),inplace=True)

# %%
X['sodium']=X['sodium'].astype("int")

# %%
X.potassium.unique()
# Out:
# array([ nan,  2.5,  3.2,  4. ,  3.7,  4.2,  5.8,  3.4,  6.4,  4.9,  4.1,
#         4.3,  5.2,  3.8,  4.6,  3.9,  4.7,  5.9,  4.8,  4.4,  6.6, 39. ,
#         5.5,  5. ,  3.5,  3.6,  7.6,  2.9,  4.5,  5.7,  5.4,  5.3, 47. ,
#         6.3,  5.1,  5.6,  3. ,  2.8,  2.7,  6.5,  3.3])

# %%
X['potassium'].fillna(X['potassium'].mean(),inplace=True)

# %%
X['potassium']=X['potassium'].astype("int")

# %%
X.hemoglobin.unique()
# Out:
# array([15.4, 11.3,  9.6, 11.2, 11.6, 12.2, 12.4, 10.8,  9.5,  9.4,  9.7,
#         9.8,  5.6,  7.6, 12.6, 12.1, 12.7, 10.3,  7.7, 10.9,  nan, 11.1,
#         9.9, 12.5, 12.9, 10.1, 12. , 13. ,  7.9,  9.3, 15. , 10. ,  8.6,
#        13.6, 10.2, 10.5,  6.6, 11. ,  7.5, 15.6, 15.2,  4.8,  9.1,  8.1,
#        11.9, 13.5,  8.3,  7.1, 16.1, 10.4,  9.2,  6.2, 13.9, 14.1,  6. ,
#        11.8, 11.7, 11.4, 14. ,  8.2, 13.2,  6.1,  8. , 12.3,  8.4, 14.3,
#         9. ,  8.7, 10.6, 13.1, 10.7,  5.5,  5.8,  6.8,  8.8,  8.5, 13.8,
#        11.5,  7.3, 13.7, 12.8, 13.4,  6.3,  3.1, 17. , 15.9, 14.5, 15.5,
#        16.2, 14.4, 14.2, 16.3, 14.8, 16.5, 15.7, 13.3, 14.6, 16.4, 16.9,
#        16. , 14.7, 16.6, 14.9, 16.7, 16.8, 15.8, 15.1, 17.1, 17.2, 15.3,
#        17.3, 17.4, 17.7, 17.8, 17.5, 17.6])

# %%
X['hemoglobin'].fillna(X['hemoglobin'].mean(),inplace=True)

# %%
X['hemoglobin']=X['hemoglobin'].astype("int")

# %%
X.packedcellvolumne.unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
X.packedcellvolumne.value_counts()
# Out:
# packedcellvolumne
# 41      21
# 52      21
# 44      19
# 48      19
# 40      16
# 43      14
# 42      13
# 45      13
# 32      12
# 36      12
# 33      12
# 50      12
# 28      12
# 34      11
# 37      11
# 30       9
# 29       9
# 35       9
# 46       9
# 31       8
# 24       7
# 39       7
# 26       6
# 38       5
# 53       4
# 51       4
# 49       4
# 47       4
# 54       4
# 25       3
# 27       3
# 22       3
# 19       2
# 23       2
# 15       1
# 21       1
# 17       1
# 20       1
# \t43     1
# 18       1
# 9        1
# 14       1
# \t?      1
# 16       1
# Name: count, dtype: int64

# %%
X['packedcellvolumne'].fillna('0',inplace=True)

# %%
X.packedcellvolumne.unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', '0',
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
X['packedcellvolumne']=X['packedcellvolumne'].replace({'\t?':'0','\t43':'0'})

# %%
X.packedcellvolumne.unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', '0',
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '52', '14',
#        '22', '18', '42', '17', '46', '23', '19', '25', '41', '26', '15',
#        '21', '43', '20', '47', '9', '49', '50', '53', '51', '54'],
#       dtype=object)

# %%
X.packedcellvolumne.isnull().sum()
# Out:
# 0

# %%
X['packedcellvolumne']=pd.to_numeric(X['packedcellvolumne'],errors='coerce')

# %%
X['packedcellvolumne']=X['packedcellvolumne'].astype("int")

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    int32
#  1   blood_pressure        400 non-null    int32
#  2   specificGravity       400 non-null    int32
#  3   aluminum              400 non-null    int32
#  4   sugar                 400 non-null    int32
#  5   redblood              400 non-null    category
#  6   pucells               400 non-null    category
#  7   bloodureanitrogen     400 non-null    int32
#  8   serumcrestine         400 non-null    int32
#  9   sodium                400 non-null    int32
#  10  potassium             400 non-null    int32
#  11  hemoglobin            400 non-null    int32
#  12  packedcellvolumne     400 non-null    int32
#  13  whitebloodcellscount  295 non-null    object
#  14  redbloodcellscount    270 non-null    object
# ...

# %%
X.whitebloodcellscount.unique()
# Out:
# array(['7800', '6000', '7500', '6700', '7300', nan, '6900', '9600',
#        '12100', '4500', '12200', '11000', '3800', '11400', '5300', '9200',
#        '6200', '8300', '8400', '10300', '9800', '9100', '7900', '6400',
#        '8600', '18900', '21600', '4300', '8500', '11300', '7200', '7700',
#        '14600', '6300', '\t6200', '7100', '11800', '9400', '5500', '5800',
#        '13200', '12500', '5600', '7000', '11900', '10400', '10700',
#        '12700', '6800', '6500', '13600', '10200', '9000', '14900', '8200',
#        '15200', '5000', '16300', '12400', '\t8400', '10500', '4200',
#        '4700', '10900', '8100', '9500', '2200', '12800', '11200', '19100',
#        '\t?', '12300', '16700', '2600', '26400', '8800', '7400', '4900',
#        '8000', '12000', '15700', '4100', '5700', '11500', '5400', '10800',
#        '9900', '5200', '5900', '9300', '9700', '5100', '6600'],
#       dtype=object)

# %%
X['whitebloodcellscount'].fillna('0',inplace=True)

# %%
X.whitebloodcellscount.value_counts()
# Out:
# whitebloodcellscount
# 0        105
# 9800      11
# 6700      10
# 9600       9
# 7200       9
#         ...
# 11200      1
# 19100      1
# \t?        1
# 12300      1
# 16700      1
# Name: count, Length: 93, dtype: int64

# %%
X['whitebloodcellscount']=X['whitebloodcellscount'].replace({'\t?':'0','\t8400':'0','\t6200':'0'})

# %%
X['whitebloodcellscount']=pd.to_numeric(X['whitebloodcellscount'],errors='coerce')

# %%
X['whitebloodcellscount']=X['whitebloodcellscount'].astype("int")

# %%
X.isnull().sum()
# Out:
# age                       0
# blood_pressure            0
# specificGravity           0
# aluminum                  0
# sugar                     0
# redblood                  0
# pucells                   0
# bloodureanitrogen         0
# serumcrestine             0
# sodium                    0
# potassium                 0
# hemoglobin                0
# packedcellvolumne         0
# whitebloodcellscount      0
# redbloodcellscount      130
# hypertension              2
# appetite                  1
# dtype: int64

# %%
X.drop('redbloodcellscount',axis=1,inplace=True)

# %%
X.hypertension.unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
X.hypertension.value_counts()
# Out:
# hypertension
# no     251
# yes    147
# Name: count, dtype: int64

# %%
X['hypertension'].fillna('no',inplace=True)

# %%
X.hypertension.isnull().sum()
# Out:
# 0

# %%
X['hypertension']=X['hypertension'].astype("category")

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    int32
#  1   blood_pressure        400 non-null    int32
#  2   specificGravity       400 non-null    int32
#  3   aluminum              400 non-null    int32
#  4   sugar                 400 non-null    int32
#  5   redblood              400 non-null    category
#  6   pucells               400 non-null    category
#  7   bloodureanitrogen     400 non-null    int32
#  8   serumcrestine         400 non-null    int32
#  9   sodium                400 non-null    int32
#  10  potassium             400 non-null    int32
#  11  hemoglobin            400 non-null    int32
#  12  packedcellvolumne     400 non-null    int32
#  13  whitebloodcellscount  400 non-null    int32
#  14  hypertension          400 non-null    category
# ...

# %%
X.appetite.unique()
# Out:
# array(['good', 'poor', nan], dtype=object)

# %%
X.appetite.value_counts()
# Out:
# appetite
# good    317
# poor     82
# Name: count, dtype: int64

# %%
X['appetite'].fillna("good",inplace=True)

# %%
X['appetite']=X['appetite'].astype("category")

# %%
X.isnull().sum()
# Out:
# age                     0
# blood_pressure          0
# specificGravity         0
# aluminum                0
# sugar                   0
# redblood                0
# pucells                 0
# bloodureanitrogen       0
# serumcrestine           0
# sodium                  0
# potassium               0
# hemoglobin              0
# packedcellvolumne       0
# whitebloodcellscount    0
# hypertension            0
# appetite                0
# dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    int32
#  1   blood_pressure        400 non-null    int32
#  2   specificGravity       400 non-null    int32
#  3   aluminum              400 non-null    int32
#  4   sugar                 400 non-null    int32
#  5   redblood              400 non-null    category
#  6   pucells               400 non-null    category
#  7   bloodureanitrogen     400 non-null    int32
#  8   serumcrestine         400 non-null    int32
#  9   sodium                400 non-null    int32
#  10  potassium             400 non-null    int32
#  11  hemoglobin            400 non-null    int32
#  12  packedcellvolumne     400 non-null    int32
#  13  whitebloodcellscount  400 non-null    int32
#  14  hypertension          400 non-null    category
# ...

# %%
import seaborn as sns
sns.boxplot(X['age'])
# Out:
# <Axes: ylabel='age'>

# %%
import numpy as np
Q1=X['age'].quantile(0.25)
Q3=X['age'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['age'].median()
X['age']=np.where((X['age']<lower_bound)|(X['age']>upper_bound),median_value,X['age'])
sns.boxplot(X['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(X['blood_pressure'])
# Out:
# <Axes: ylabel='blood_pressure'>

# %%
Q1=X['blood_pressure'].quantile(0.25)
Q3=X['blood_pressure'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['blood_pressure'].median()
X['blood_pressure']=np.where((X['blood_pressure']<lower_bound)|(X['blood_pressure']>upper_bound),median_value,X['blood_pressure'])
sns.boxplot(X['blood_pressure'])
# Out:
# <Axes: ylabel='blood_pressure'>

# %%
sns.boxplot(X['specificGravity'])
# Out:
# <Axes: ylabel='specificGravity'>

# %%
sns.boxplot(X['aluminum'])
# Out:
# <Axes: ylabel='aluminum'>

# %%
sns.boxplot(X['sugar'])
# Out:
# <Axes: ylabel='sugar'>

# %%
X.sugar.value_counts()
# Out:
# sugar
# 0    339
# 2     18
# 3     14
# 4     13
# 1     13
# 5      3
# Name: count, dtype: int64

# %%
Q1=X['sugar'].quantile(0.25)
Q3=X['sugar'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['sugar'].median()
X['sugar']=np.where((X['sugar']<lower_bound)|(X['sugar']>upper_bound),median_value,X['sugar'])
sns.boxplot(X['sugar'])
# Out:
# <Axes: ylabel='sugar'>

# %%
X
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar redblood  \
# 0    48.0            80.0                1         1    0.0   normal
# 1    54.0            78.0                1         4    0.0   normal
# 2    62.0            80.0                1         2    0.0   normal
# 3    48.0            70.0                1         4    0.0   normal
# 4    51.0            80.0                1         2    0.0   normal
# ..    ...             ...              ...       ...    ...      ...
# 395  55.0            80.0                1         0    0.0   normal
# 396  42.0            70.0                1         0    0.0   normal
# 397  12.0            80.0                1         0    0.0   normal
# 398  17.0            60.0                1         0    0.0   normal
# 399  58.0            80.0                1         0    0.0   normal
#
#       pucells  bloodureanitrogen  serumcrestine  sodium  potassium  \
# 0      normal                121              1     137          4
# ...

# %%
sns.boxplot(X['bloodureanitrogen'])
# Out:
# <Axes: ylabel='bloodureanitrogen'>

# %%
Q1=X['bloodureanitrogen'].quantile(0.25)
Q3=X['bloodureanitrogen'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['bloodureanitrogen'].median()
X['bloodureanitrogen']=np.where((X['bloodureanitrogen']<lower_bound)|(X['bloodureanitrogen']>upper_bound),median_value,X['bloodureanitrogen'])
sns.boxplot(X['bloodureanitrogen'])
# Out:
# <Axes: ylabel='bloodureanitrogen'>

# %%
sns.boxplot(X['serumcrestine'])
# Out:
# <Axes: ylabel='serumcrestine'>

# %%
Q1=X['serumcrestine'].quantile(0.25)
Q3=X['serumcrestine'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['serumcrestine'].median()
X['serumcrestine']=np.where((X['serumcrestine']<lower_bound)|(X['serumcrestine']>upper_bound),median_value,X['serumcrestine'])
sns.boxplot(X['serumcrestine'])
# Out:
# <Axes: ylabel='serumcrestine'>

# %%
sns.boxplot(X['sodium'])
# Out:
# <Axes: ylabel='sodium'>

# %%
Q1=X['sodium'].quantile(0.25)
Q3=X['sodium'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['sodium'].median()
X['sodium']=np.where((X['sodium']<lower_bound)|(X['sodium']>upper_bound),median_value,X['sodium'])
sns.boxplot(X['sodium'])
# Out:
# <Axes: ylabel='sodium'>

# %%
sns.boxplot(X['potassium'])
# Out:
# <Axes: ylabel='potassium'>

# %%
Q1=X['potassium'].quantile(0.25)
Q3=X['potassium'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
median_value=X['potassium'].median()
X['potassium']=np.where((X['potassium']<lower_bound)|(X['potassium']>upper_bound),median_value,X['potassium'])
sns.boxplot(X['potassium'])
# Out:
# <Axes: ylabel='potassium'>

# %%
sns.boxplot(X['hemoglobin'])
# Out:
# <Axes: ylabel='hemoglobin'>

# %%
sns.boxplot(X['packedcellvolumne'])
# Out:
# <Axes: ylabel='packedcellvolumne'>

# %%
sns.boxplot(X['whitebloodcellscount'])
# Out:
# <Axes: ylabel='whitebloodcellscount'>

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    float64
#  1   blood_pressure        400 non-null    float64
#  2   specificGravity       400 non-null    int32
#  3   aluminum              400 non-null    int32
#  4   sugar                 400 non-null    float64
#  5   redblood              400 non-null    category
#  6   pucells               400 non-null    category
#  7   bloodureanitrogen     400 non-null    float64
#  8   serumcrestine         400 non-null    float64
#  9   sodium                400 non-null    float64
#  10  potassium             400 non-null    float64
#  11  hemoglobin            400 non-null    int32
#  12  packedcellvolumne     400 non-null    int32
#  13  whitebloodcellscount  400 non-null    int32
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['redblood']=le.fit_transform(X['redblood'])

# %%
X
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 0    48.0            80.0                1         1    0.0         1
# 1    54.0            78.0                1         4    0.0         1
# 2    62.0            80.0                1         2    0.0         1
# 3    48.0            70.0                1         4    0.0         1
# 4    51.0            80.0                1         2    0.0         1
# ..    ...             ...              ...       ...    ...       ...
# 395  55.0            80.0                1         0    0.0         1
# 396  42.0            70.0                1         0    0.0         1
# 397  12.0            80.0                1         0    0.0         1
# 398  17.0            60.0                1         0    0.0         1
# 399  58.0            80.0                1         0    0.0         1
#
#       pucells  bloodureanitrogen  serumcrestine  sodium  potassium  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['pucells']=le.fit_transform(X['pucells'])

# %%
X
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 0    48.0            80.0                1         1    0.0         1
# 1    54.0            78.0                1         4    0.0         1
# 2    62.0            80.0                1         2    0.0         1
# 3    48.0            70.0                1         4    0.0         1
# 4    51.0            80.0                1         2    0.0         1
# ..    ...             ...              ...       ...    ...       ...
# 395  55.0            80.0                1         0    0.0         1
# 396  42.0            70.0                1         0    0.0         1
# 397  12.0            80.0                1         0    0.0         1
# 398  17.0            60.0                1         0    0.0         1
# 399  58.0            80.0                1         0    0.0         1
#
#      pucells  bloodureanitrogen  serumcrestine  sodium  potassium  hemoglobin  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['hypertension']=le.fit_transform(X['hypertension'])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['appetite']=le.fit_transform(X['appetite'])

# %%
X
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 0    48.0            80.0                1         1    0.0         1
# 1    54.0            78.0                1         4    0.0         1
# 2    62.0            80.0                1         2    0.0         1
# 3    48.0            70.0                1         4    0.0         1
# 4    51.0            80.0                1         2    0.0         1
# ..    ...             ...              ...       ...    ...       ...
# 395  55.0            80.0                1         0    0.0         1
# 396  42.0            70.0                1         0    0.0         1
# 397  12.0            80.0                1         0    0.0         1
# 398  17.0            60.0                1         0    0.0         1
# 399  58.0            80.0                1         0    0.0         1
#
#      pucells  bloodureanitrogen  serumcrestine  sodium  potassium  hemoglobin  \
# ...

# %%
Y
# Out:
#      status
# 0       ckd
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# ..      ...
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [400 rows x 1 columns]

# %%
Y.status.unique()
# Out:
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
Y.value_counts()
# Out:
# status
# ckd       248
# notckd    150
# ckd\t       2
# Name: count, dtype: int64

# %%
Y['status']=Y['status'].replace({"ckd\t":"ckd"})

# %%
Y.value_counts()
# Out:
# status
# ckd       250
# notckd    150
# Name: count, dtype: int64

# %%
Y['status']=Y['status'].astype("category")

# %%
Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   status  400 non-null    category
# dtypes: category(1)
# memory usage: 656.0 bytes

# %%
Y
# Out:
#      status
# 0       ckd
# 1       ckd
# 2       ckd
# 3       ckd
# 4       ckd
# ..      ...
# 395  notckd
# 396  notckd
# 397  notckd
# 398  notckd
# 399  notckd
#
# [400 rows x 1 columns]

# %%
Y.value_counts()
# Out:
# status
# 0         250
# 1         150
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 0    48.0            80.0                1         1    0.0         1
# 1    54.0            78.0                1         4    0.0         1
# 2    62.0            80.0                1         2    0.0         1
# 3    48.0            70.0                1         4    0.0         1
# 4    51.0            80.0                1         2    0.0         1
# ..    ...             ...              ...       ...    ...       ...
# 395  55.0            80.0                1         0    0.0         1
# 396  42.0            70.0                1         0    0.0         1
# 397  12.0            80.0                1         0    0.0         1
# 398  17.0            60.0                1         0    0.0         1
# 399  58.0            80.0                1         0    0.0         1
#
#      pucells  bloodureanitrogen  serumcrestine  sodium  potassium  hemoglobin  \
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8,test_size=0.2,random_state=42)

# %%
X_train
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 3    48.0            70.0                1         4    0.0         1
# 18   60.0            78.0                1         0    0.0         1
# 202  78.0            60.0                1         1    0.0         1
# 250  40.0            80.0                1         0    0.0         1
# 274  19.0            80.0                1         0    0.0         1
# ..    ...             ...              ...       ...    ...       ...
# 71   46.0            60.0                1         1    0.0         1
# 106  50.0            90.0                1         1    0.0         1
# 270  23.0            80.0                1         0    0.0         1
# 348  38.0            80.0                1         0    0.0         1
# 102  17.0            60.0                1         0    0.0         1
#
#      pucells  bloodureanitrogen  serumcrestine  sodium  potassium  hemoglobin  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
kidmodel=LogisticRegression()

# %%
kidmodel.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_pred=kidmodel.predict(X_test)

# %%
Y_pred
# Out:
# array(['ckd', 'notckd', 'ckd', 'ckd', 'ckd', 'ckd', 'notckd', 'ckd',
#        'ckd', 'ckd', 'ckd', 'notckd', 'ckd', 'ckd', 'ckd', 'ckd',
#        'notckd', 'notckd', 'ckd', 'notckd', 'ckd', 'ckd', 'notckd',
#        'notckd', 'notckd', 'notckd', 'ckd', 'ckd', 'notckd', 'ckd',
#        'notckd', 'ckd', 'notckd', 'ckd', 'ckd', 'ckd', 'ckd', 'notckd',
#        'ckd', 'ckd', 'notckd', 'ckd', 'ckd', 'ckd', 'ckd', 'notckd',
#        'ckd', 'ckd', 'ckd', 'ckd', 'ckd', 'notckd', 'notckd', 'notckd',
#        'notckd', 'ckd', 'ckd', 'ckd', 'ckd', 'ckd', 'ckd', 'notckd',
#        'notckd', 'ckd', 'ckd', 'ckd', 'notckd', 'notckd', 'notckd', 'ckd',
#        'notckd', 'ckd', 'ckd', 'ckd', 'notckd', 'ckd', 'ckd', 'notckd',
#        'ckd', 'notckd'], dtype=object)

# %%
from sklearn.metrics import classification_report
full_report=classification_report(Y_pred,Y_test)

# %%
print(full_report)
# Out:
#               precision    recall  f1-score   support
#
#          ckd       0.96      0.98      0.97        51
#       notckd       0.96      0.93      0.95        29
#
#     accuracy                           0.96        80
#    macro avg       0.96      0.96      0.96        80
# weighted avg       0.96      0.96      0.96        80

# %%
X_test
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 209  19.0            70.0                1         0    0.0         1
# 280  47.0            80.0                1         1    0.0         1
# 33   60.0            78.0                1         2    0.0         0
# 210  59.0            78.0                1         4    0.0         1
# 93   73.0            78.0                1         3    0.0         0
# ..    ...             ...              ...       ...    ...       ...
# 246  48.0            78.0                1         3    0.0         0
# 227  57.0            80.0                1         0    0.0         1
# 369  75.0            70.0                1         0    0.0         1
# 176  21.0            90.0                1         4    0.0         1
# 289  42.0            70.0                1         0    0.0         1
#
#      pucells  bloodureanitrogen  serumcrestine  sodium  potassium  hemoglobin  \
# ...

# %%
X_train
# Out:
#       age  blood_pressure  specificGravity  aluminum  sugar  redblood  \
# 3    48.0            70.0                1         4    0.0         1
# 18   60.0            78.0                1         0    0.0         1
# 202  78.0            60.0                1         1    0.0         1
# 250  40.0            80.0                1         0    0.0         1
# 274  19.0            80.0                1         0    0.0         1
# ..    ...             ...              ...       ...    ...       ...
# 71   46.0            60.0                1         1    0.0         1
# 106  50.0            90.0                1         1    0.0         1
# 270  23.0            80.0                1         0    0.0         1
# 348  38.0            80.0                1         0    0.0         1
# 102  17.0            60.0                1         0    0.0         1
#
#      pucells  bloodureanitrogen  serumcrestine  sodium  potassium  hemoglobin  \
# ...

# %%
Y_train
# Out:
#      status
# 3       ckd
# 18      ckd
# 202     ckd
# 250  notckd
# 274  notckd
# ..      ...
# 71      ckd
# 106     ckd
# 270  notckd
# 348  notckd
# 102     ckd
#
# [320 rows x 1 columns]

# %%
Y_test
# Out:
#      status
# 209     ckd
# 280  notckd
# 33      ckd
# 210     ckd
# 93      ckd
# ..      ...
# 246     ckd
# 227     ckd
# 369  notckd
# 176     ckd
# 289  notckd
#
# [80 rows x 1 columns]

# %%
X.head(34)
# Out:
#      age  blood_pressure  specificGravity  aluminum  sugar  redblood  pucells  \
# 0   48.0            80.0                1         1    0.0         1        1
# 1   54.0            78.0                1         4    0.0         1        1
# 2   62.0            80.0                1         2    0.0         1        1
# 3   48.0            70.0                1         4    0.0         1        0
# 4   51.0            80.0                1         2    0.0         1        1
# 5   60.0            90.0                1         3    0.0         1        1
# 6   68.0            70.0                1         0    0.0         1        1
# 7   24.0            76.0                1         2    0.0         1        0
# 8   52.0            78.0                1         3    0.0         1        0
# 9   53.0            90.0                1         2    0.0         0        0
# 10  50.0            60.0                1         2    0.0         1        0
# ...

# %%
inputdata = (60.0,78.0,1,2,0.0,0,0,140.0,2.0,137.0,4.0,10,29,0,1,1)
inputdataasarray = np.asarray(inputdata)
inputdatareshaped = inputdataasarray.reshape(1,-1)
prediction = kidmodel.predict((inputdatareshaped))
print(*prediction)
# Out:
# ckd

# %%
import pickle
with open('kidneymodel.pkl','wb')as file:
    pickle.dump(kidmodel,file)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   400 non-null    float64
#  1   blood_pressure        400 non-null    float64
#  2   specificGravity       400 non-null    int32
#  3   aluminum              400 non-null    int32
#  4   sugar                 400 non-null    float64
#  5   redblood              400 non-null    int32
#  6   pucells               400 non-null    int32
#  7   bloodureanitrogen     400 non-null    float64
#  8   serumcrestine         400 non-null    float64
#  9   sodium                400 non-null    float64
#  10  potassium             400 non-null    float64
#  11  hemoglobin            400 non-null    int32
#  12  packedcellvolumne     400 non-null    int32
#  13  whitebloodcellscount  400 non-null    int32
#  14  hypertension          400 non-null    int32
# ...
